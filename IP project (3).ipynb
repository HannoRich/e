# %%
import csv
import pandas as pd
Buses=pd.read_csv('C:\\Users\\hanno\\OneDrive\\Documents\\Custom Office Templates\\ip_project.csv',index_col=0)
Buses
# Out:
#              Bus_No Passenger_Name    Phone_No     Aadhar_No  No_Of_Passenger  \
# Passenge_No
# 1               101      Lal Patel  6986533598  727783774214                1
# 2               126            Raj  8368609044  684932071480                3
# 3               126            Tom  4753819025  739201739021                2
# 4               126          Sohan  9025671936  860262959217                1
# 5               112          Rahul  9015782340  748102351967                4
# 6               112          Shiva  7391024517  931629017891                1
# 7               132           Raju  7910347196  201789174516                2
# 8               132         Seetha  6801537198  820185610927                1
# 9               108          Abdul  9103728547  759014276018                6
# 10              122        Abraham  2710561839  371058201592                1
# 11              122          Reeta  9016278156  515378915379                2
# ...
